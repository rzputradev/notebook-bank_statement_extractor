# %%
import json

file_path = 'sample/extracted/bri-statement_transaction.json'

with open(file_path, 'r') as file:
    data = json.load(file)

def check_balance_validity(transactions):
    previous_balance = None
    results = []

    for transaction in transactions:
        current_balance = transaction['balance']['value']
        debit = transaction['debit']['value']
        credit = transaction['credit']['value']

        if previous_balance is None:
            calculated_balance = current_balance
        else:
            calculated_balance = previous_balance + credit - debit

        is_valid = (calculated_balance == current_balance)
        results.append({
            "id": transaction['id'],
            "previous_balance":previous_balance,
            "debit_credit": credit - debit,
            "calculated_balance": calculated_balance,
            "current_balance": current_balance,            
            "validity": is_valid
            
        })

        previous_balance = current_balance

    return results

validity_results = check_balance_validity(data['transactions'])
validity_results
# Out:
# [{'id': 0,
#   'previous_balance': None,
#   'debit_credit': -500000000,
#   'calculated_balance': 3722492254,
#   'current_balance': 3722492254,
#   'validity': True},
#  {'id': 1,
#   'previous_balance': 3722492254,
#   'debit_credit': -150000,
#   'calculated_balance': 3722342254,
#   'current_balance': 3722342254,
#   'validity': True},
#  {'id': 2,
#   'previous_balance': 3722342254,
#   'debit_credit': -580000000,
#   'calculated_balance': 3142342254,
#   'current_balance': 3142342254,
#   'validity': True},
#  {'id': 3,
#   'previous_balance': 3142342254,
#   'debit_credit': -85140000,
#   'calculated_balance': 3057202254,
#   'current_balance': 3057202254,
#   'validity': True},
#  {'id': 4,
#   'previous_balance': 3057202254,
#   'debit_credit': 10010000,
#   'calculated_balance': 3067212254,
#   'current_balance': 3067212254,
#   'validity': True},
#  {'id': 5,
#   'previous_balance': 3067212254,
#   'debit_credit': -111119509,
#   'calculated_balance': 2956092745,
#   'current_balance': 2956092745,
#   'validity': True},
#  {'id': 6,
#   'previous_balance': 2956092745,
#   'debit_credit': -20000000,
#   'calculated_balance': 2936092745,
#   'current_balance': 2936092745,
#   'validity': True},
#  {'id': 7,
#   'previous_balance': 2936092745,
#   'debit_credit': -131000000,
#   'calculated_balance': 2805092745,
#   'current_balance': 2805092745,
#   'validity': True},
#  {'id': 8,
#   'previous_balance': 2805092745,
#   'debit_credit': 2238694670,
#   'calculated_balance': 5043787415,
#   'current_balance': 5043787415,
#   'validity': True},
#  {'id': 9,
#   'previous_balance': 5043787415,
#   'debit_credit': 14280000,
#   'calculated_balance': 5058067415,
#   'current_balance': 5058067415,
#   'validity': True},
#  {'id': 10,
#   'previous_balance': 5058067415,
#   'debit_credit': 14250000,
#   'calculated_balance': 5072317415,
#   'current_balance': 5072317415,
#   'validity': True},
#  {'id': 11,
#   'previous_balance': 5072317415,
#   'debit_credit': 269095000,
#   'calculated_balance': 5341412415,
#   'current_balance': 5341412415,
#   'validity': True},
#  {'id': 12,
#   'previous_balance': 5341412415,
#   'debit_credit': 2238634670,
#   'calculated_balance': 7580047085,
#   'current_balance': 7580047085,
#   'validity': True},
#  {'id': 13,
#   'previous_balance': 7580047085,
#   'debit_credit': -400000000,
#   'calculated_balance': 7180047085,
#   'current_balance': 7180047085,
#   'validity': True},
#  {'id': 14,
#   'previous_balance': 7180047085,
#   'debit_credit': -43000000,
#   'calculated_balance': 7137047085,
#   'current_balance': 7137047085,
#   'validity': True},
#  {'id': 15,
#   'previous_balance': 7137047085,
#   'debit_credit': 300000000,
#   'calculated_balance': 7437047085,
#   'current_balance': 7437047085,
#   'validity': True},
#  {'id': 16,
#   'previous_balance': 7437047085,
#   'debit_credit': -500000000,
#   'calculated_balance': 6937047085,
#   'current_balance': 6937047085,
#   'validity': True},
#  {'id': 17,
#   'previous_balance': 6937047085,
#   'debit_credit': -85000000,
#   'calculated_balance': 6852047085,
#   'current_balance': 6852047085,
#   'validity': True},
#  {'id': 18,
#   'previous_balance': 6852047085,
#   'debit_credit': -200000000,
#   'calculated_balance': 6652047085,
#   'current_balance': 6652047085,
#   'validity': True},
#  {'id': 19,
#   'previous_balance': 6652047085,
#   'debit_credit': -25500000,
#   'calculated_balance': 6626547085,
#   'current_balance': 6626547085,
#   'validity': True},
#  {'id': 20,
#   'previous_balance': 6626547085,
#   'debit_credit': 654545455,
#   'calculated_balance': 7281092540,
#   'current_balance': 7281092540,
#   'validity': True},
#  {'id': 21,
#   'previous_balance': 7281092540,
#   'debit_credit': 5000000000,
#   'calculated_balance': 12281092540,
#   'current_balance': 12281092540,
#   'validity': True},
#  {'id': 22,
#   'previous_balance': 12281092540,
#   'debit_credit': -300000000,
#   'calculated_balance': 11981092540,
#   'current_balance': 11981092540,
#   'validity': True},
#  {'id': 23,
#   'previous_balance': 11981092540,
#   'debit_credit': 7438600,
#   'calculated_balance': 11988531140,
#   'current_balance': 11988531140,
#   'validity': True},
#  {'id': 24,
#   'previous_balance': 11988531140,
#   'debit_credit': -1487720,
#   'calculated_balance': 11987043420,
#   'current_balance': 11987043420,
#   'validity': True},
#  {'id': 25,
#   'previous_balance': 11987043420,
#   'debit_credit': -1847547000,
#   'calculated_balance': 10139496420,
#   'current_balance': 10139496420,
#   'validity': True},
#  {'id': 26,
#   'previous_balance': 10139496420,
#   'debit_credit': 260000000,
#   'calculated_balance': 10399496420,
#   'current_balance': 10399496420,
#   'validity': True},
#  {'id': 27,
#   'previous_balance': 10399496420,
#   'debit_credit': -150000,
#   'calculated_balance': 10399346420,
#   'current_balance': 10399346420,
#   'validity': True},
#  {'id': 28,
#   'previous_balance': 10399346420,
#   'debit_credit': -300000,
#   'calculated_balance': 10399046420,
#   'current_balance': 10399046420,
#   'validity': True},
#  {'id': 29,
#   'previous_balance': 10399046420,
#   'debit_credit': 400000000,
#   'calculated_balance': 10799046420,
#   'current_balance': 10799046420,
#   'validity': True},
#  {'id': 30,
#   'previous_balance': 10799046420,
#   'debit_credit': 1286400,
#   'calculated_balance': 10800332820,
#   'current_balance': 10800332820,
#   'validity': True},
#  {'id': 31,
#   'previous_balance': 10800332820,
#   'debit_credit': 14472400,
#   'calculated_balance': 10814805220,
#   'current_balance': 10814805220,
#   'validity': True},
#  {'id': 32,
#   'previous_balance': 10814805220,
#   'debit_credit': 22400900,
#   'calculated_balance': 10837206120,
#   'current_balance': 10837206120,
#   'validity': True},
#  {'id': 33,
#   'previous_balance': 10837206120,
#   'debit_credit': 8563400,
#   'calculated_balance': 10845769520,
#   'current_balance': 10845769520,
#   'validity': True},
#  {'id': 34,
#   'previous_balance': 10845769520,
#   'debit_credit': -8635000000,
#   'calculated_balance': 2210769520,
#   'current_balance': 2210769520,
#   'validity': True}]
